# %% [markdown]
# # 探究保健品市场环境数据分析

# %%
import numpy as  np
import pandas as pd

# %%
data = pd.read_csv('保健品.csv')
sub_data = data.loc[:20]
# print(sub_data)
data.head()
# Out:
#     q5_01  q5_02  q5_03  q5_04  q5_05  q5_06  q5_07  q5_08  q5_09  q5_10  ...  \
# 0       3      3      4      5      5      5      4      5      3      4  ...
# 1       5      4      5      5      5      5      5      4      4      4  ...
# 2       5      5      5      5      1      1      4      1      1      1  ...
# 3       3      5      5      1      1      1      4      5      4      4  ...
# 4       5      4      2      2      3      4      4      3      4      3  ...
# 5       5      5      4      3      1      3      4      4      3      3  ...
# 6       5      5      3      2      2      2      5      4      3      5  ...
# 7       4      5      5      1      1      2      5      3      5      1  ...
# 8       4      3      4      5      3      4      4      3      4      4  ...
# 9       5      5      4      2      1      3      2      2      5      3  ...
# 10      4      3      5      4      1      4      3      5      3      4  ...
# ...

# %%
desc = sub_data.describe()
desc
# Out:
#            q5_01      q5_02      q5_03      q5_04      q5_05      q5_06  \
# count  21.000000  21.000000  21.000000  21.000000  21.000000  21.000000
# mean    4.285714   4.333333   4.380952   3.047619   2.523810   3.190476
# std     0.956183   0.856349   0.864650   1.627151   1.569046   1.569046
# min     2.000000   3.000000   2.000000   1.000000   1.000000   1.000000
# 25%     4.000000   4.000000   4.000000   2.000000   1.000000   2.000000
# 50%     5.000000   5.000000   5.000000   3.000000   2.000000   3.000000
# 75%     5.000000   5.000000   5.000000   5.000000   4.000000   5.000000
# max     5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
#
#            q5_07      q5_08      q5_09      q5_10  ...      q5_15      q5_16  \
# count  21.000000  21.000000  21.000000  21.000000  ...  21.000000  21.000000
# mean    3.904762   3.619048   3.761905   3.809524  ...   4.047619   3.809524
# std     1.220851   1.283596   1.220851   1.209093  ...   1.116969   1.364516
# ...

# %%
desc.loc['mean'].sort_values(ascending=False)
# Out:
# w6       11.380952
# q8        9.000000
# q5_03     4.380952
# q5_02     4.333333
# q5_01     4.285714
# q5_15     4.047619
# q5_07     3.904762
# q5_10     3.809524
# q5_16     3.809524
# q5_14     3.809524
# q5_11     3.809524
# q5_09     3.761905
# q5_08     3.619048
# w2        3.476190
# q5_13     3.285714
# q5_20     3.190476
# q5_06     3.190476
# q5_12     3.095238
# q5_04     3.047619
# q5_19     2.952381
# q5_18     2.904762
# q5_05     2.523810
# q5_17     2.285714
# w1        1.476190
# Name: mean, dtype: float64
